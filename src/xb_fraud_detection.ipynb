# %%
import pandas as pd

# %% [raw]
# ## 读取数据

# %%
credit = pd.read_csv('../data/credit.csv')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36457 entries, 0 to 36456
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           36457 non-null  int64
#  1   ID                   36457 non-null  int64
#  2   CODE_GENDER          36457 non-null  object
#  3   FLAG_OWN_CAR         36457 non-null  object
#  4   FLAG_OWN_REALTY      36457 non-null  object
#  5   CNT_CHILDREN         36457 non-null  int64
#  6   AMT_INCOME_TOTAL     36457 non-null  float64
#  7   NAME_INCOME_TYPE     36457 non-null  object
#  8   NAME_EDUCATION_TYPE  36457 non-null  object
#  9   NAME_FAMILY_STATUS   36457 non-null  object
#  10  NAME_HOUSING_TYPE    36457 non-null  object
#  11  DAYS_BIRTH           36457 non-null  int64
#  12  DAYS_EMPLOYED        36457 non-null  int64
#  13  FLAG_MOBIL           36457 non-null  int64
#  14  FLAG_WORK_PHONE      36457 non-null  int64
#  15  FLAG_PHONE           36457 non-null  int64
#  16  FLAG_EMAIL           36457 non-null  int64
#  17  OCCUPATION_TYPE      25134 non-null  object
#  18  CNT_FAM_MEMBERS      36457 non-null  float64
#  19  begin_month          36457 non-null  float64
#  20  dep_value            36457 non-null  object
#  21  target               36457 non-null  int64
# dtypes: float64(3), int64(10), object(9)
# memory usage: 6.1+ MB

# %%
credit.head()
# Out:
#    Unnamed: 0       ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0           0  5008804           M            Y               Y             0
# 1           1  5008805           M            Y               Y             0
# 2           2  5008806           M            Y               Y             0
# 3           3  5008808           F            N               Y             0
# 4           4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  ... DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0        Civil marriage  ...         -4542           1                1
# 1        Civil marriage  ...         -4542           1                1
# 2               Married  ...         -1134           1                0
# 3  Single / not married  ...         -3051           1                0
# 4  Single / not married  ...         -3051           1                0
#
#    FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS begin_month  \
# 0           0           0              NaN              2.0       -15.0
# 1           0           0              NaN              2.0       -14.0
# 2           0           0   Security staff              2.0       -29.0
# 3           1           1      Sales staff              1.0        -4.0
# 4           1           1      Sales staff              1.0       -26.0
#
#    dep_value  target
# 0         No       0
# 1         No       0
# 2         No       0
# 3         No       0
# 4         No       0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 丢弃无用columns

# %%
credit = credit.drop(columns=['Unnamed: 0','dep_value'], axis=1)
credit.info()

# %% [markdown]
# ## 处理columns

# %%
credit['month_on_book'] = -credit['begin_month']
# 将年龄和工龄转换为年
credit['DAYS_BIRTH'] = -credit['DAYS_BIRTH'] / 365
credit['DAYS_EMPLOYED'] = credit['DAYS_EMPLOYED'] / 365
credit.rename(columns={'DAYS_BIRTH': 'age', 'DAYS_EMPLOYED':'work_year'}, inplace=True)
credit.drop(columns='begin_month', axis=1, inplace=True)
# 将工资按照 'k'为单位
credit['AMT_INCOME_TOTAL'] = credit['AMT_INCOME_TOTAL'] / 1000
# 处理flag类二分数据
dic = {'Y': 1, 'N': 0}
credit['FLAG_OWN_CAR'] = credit['FLAG_OWN_CAR'].replace(dic)
credit['FLAG_OWN_REALTY'] = credit['FLAG_OWN_REALTY'].replace(dic)
credit['CODE_GENDER'] = credit['CODE_GENDER'].replace({'M':1, 'F':0})

# %%
credit.head()
# Out:
#         ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804            1             1                1             0
# 1  5008805            1             1                1             0
# 2  5008806            1             1                1             0
# 3  5008808            0             0                1             0
# 4  5008809            0             0                1             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0             427.5               Working               Higher education
# 1             427.5               Working               Higher education
# 2             112.5               Working  Secondary / secondary special
# 3             270.0  Commercial associate  Secondary / secondary special
# 4             270.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE        age  work_year  FLAG_MOBIL  \
# 0        Civil marriage   Rented apartment  32.890411 -12.443836           1
# 1        Civil marriage   Rented apartment  32.890411 -12.443836           1
# 2               Married  House / apartment  58.832877  -3.106849           1
# 3  Single / not married  House / apartment  52.356164  -8.358904           1
# 4  Single / not married  House / apartment  52.356164  -8.358904           1
#
#    FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# 0                1           0           0             NaN              2.0
# 1                1           0           0             NaN              2.0
# 2                0           0           0  Security staff              2.0
# 3                0           1           1     Sales staff              1.0
# 4                0           1           1     Sales staff              1.0
#
#    target  month_on_book
# 0       0           15.0
# 1       0           14.0
# 2       0           29.0
# 3       0            4.0
# 4       0           26.0

# %%
credit.isna().sum()
# Out:
# ID                         0
# CODE_GENDER                0
# FLAG_OWN_CAR               0
# FLAG_OWN_REALTY            0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# NAME_HOUSING_TYPE          0
# age                        0
# work_year                  0
# FLAG_MOBIL                 0
# FLAG_WORK_PHONE            0
# FLAG_PHONE                 0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        11323
# CNT_FAM_MEMBERS            0
# target                     0
# month_on_book              0
# dtype: int64

# %% [markdown]
# 可以看出职业一栏有许多空数据

# %%
# 对于缺失的工作column，我们设其为新的一类值 'Unknown'
credit['OCCUPATION_TYPE'] = credit['OCCUPATION_TYPE'].fillna('Unknown')

# %%
credit['OCCUPATION_TYPE']
# Out:
# 0               Unknown
# 1               Unknown
# 2        Security staff
# 3           Sales staff
# 4           Sales staff
#               ...
# 36452          Managers
# 36453    Medicine staff
# 36454    Medicine staff
# 36455       Sales staff
# 36456          Laborers
# Name: OCCUPATION_TYPE, Length: 36457, dtype: object

# %% [markdown]
# 这样就处理了工作类型的缺失值

# %% [markdown]
# ## 数据分析及处理

# %%
# 二分类对应列
flag_col = [i for i in credit.columns if i.startswith('FLAG_')]

# %%
from matplotlib import pyplot as plt

# %%
_, axes = plt.subplots(ncols=len(flag_col), figsize=(30, 5))
for col, ax in zip(flag_col, axes):
    credit[col].value_counts().plot(kind='bar', ax=ax, title=col)
plt.show()

# %%
# 由上图可知，FLAG_MOBIL全部为1，显然可以消除
credit.drop(columns='FLAG_MOBIL', axis=1, inplace=True)

# %%
name_cols = [col for col in credit.columns if col.startswith('NAME_')]

# %%
_, axes = plt.subplots(nrows=len(name_cols), figsize=(5, 20))
for col, ax in zip(name_cols, axes):
    credit[col].value_counts().plot(kind='barh', ax=ax, title=col)
plt.show()

# %%
amt_cols = ['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'CNT_FAM_MEMBERS', 'month_on_book', 'age', 'work_year']

# %%
import seaborn as sns

# %%
_, axes = plt.subplots(nrows=len(amt_cols), figsize=(10, 20))
for col, ax in zip(amt_cols, axes):
    sns.distplot(credit[col], ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_on_book'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-33fa784f4c5e> in <module>
#       1 _, axes = plt.subplots(nrows=len(amt_cols), figsize=(10, 20))
#       2 for col, ax in zip(amt_cols, axes):
# ----> 3     sns.distplot(credit[col], ax=ax)
#       4 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_on_book'

# %%
desc = round(credit[amt_cols].describe(), 0)
desc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-e024351b1258> in <module>
# ----> 1 desc = round(credit[amt_cols].describe(), 0)
#       2 desc
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['month_on_book', 'work_year', 'age'] not in index"

# %%
credit[credit['work_year'] > 0]
# Out:
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 7      5008812            0             0                1             0
# 8      5008813            0             0                1             0
# 9      5008814            0             0                1             0
# 69     5008884            0             0                1             0
# 150    5008974            0             0                1             0
# 151    5008975            0             0                1             0
# 152    5008976            0             0                1             0
# 153    5008977            0             0                1             0
# 154    5008978            0             0                1             0
# 155    5008979            0             0                1             0
# 156    5008980            0             0                1             0
# 196    5009033            0             0                0             0
# 197    5009034            0             0                0             0
# 36434                0           0           0         Unknown
# 36439                0           0           0         Unknown
#
#        CNT_FAM_MEMBERS  target  month_on_book
# 7                  1.0       0           20.0
# 8                  1.0       0           16.0
# 9                  1.0       0           17.0
# 69                 1.0       0           40.0
# 150                2.0       0           49.0
# 151                2.0       0           49.0
# 152                2.0       0            1.0
# 153                2.0       0           23.0
# 154                2.0       0           38.0
# 155                2.0       0           37.0
# 156                2.0       0           58.0
# 196                2.0       0           16.0
# 197                2.0       0           31.0
# 198                2.0       0            5.0
# 199                2.0       0           18.0
# 200                2.0       0           19.0
# 201                2.0       0           12.0
# 218                2.0       0            3.0
# 271                1.0       0           16.0
# 272                1.0       0           16.0
# 273                1.0       0           55.0
# 274                1.0       0           15.0
# 275                1.0       0           11.0
# 276                1.0       0           22.0
# 277                1.0       0            8.0
# 278                1.0       0           18.0
# 281                2.0       0           11.0
# 282                2.0       0           15.0
# 305                2.0       0           30.0
# 371                1.0       0           21.0
# ...                ...     ...            ...
# 36320              2.0       1           43.0
# 36322              1.0       1           11.0
# 36325              1.0       1           45.0
# 36327              2.0       1            9.0
# 36337              2.0       1           18.0
# 36345              2.0       1           42.0
# 36348              3.0       1           19.0
# 36353              1.0       1           18.0
# 36354              2.0       1           43.0
# 36355              2.0       1            9.0
# 36367              2.0       1           15.0
# 36368              2.0       1            7.0
# 36369              2.0       1           29.0
# 36370              2.0       1           27.0
# 36371              2.0       1           23.0
# 36373              1.0       1           43.0
# 36381              1.0       1           27.0
# 36385              1.0       1           12.0
# 36386              2.0       1           24.0
# 36387              2.0       1           39.0
# 36388              2.0       1           48.0
# 36389              2.0       1           39.0
# 36405              2.0       1            6.0
# 36406              2.0       1           44.0
# 36407              2.0       1           15.0
# 36408              2.0       1           28.0
# 36418              1.0       1           16.0
# 36432              2.0       1           17.0
# 36434              2.0       1           39.0
# 36439              2.0       1           15.0
#
# [6135 rows x 19 columns]

# %% [markdown]
# 有6135条数据存在work_year异常值，且全部为退休人员

# %%
# 使用插值法，将异常值替换为去掉异常值之后的平均值
credit.loc[credit['work_year'] > 0, 'work_year'] = credit[credit['work_year'] < 0]['work_year'].mean()
credit['work_year'] = -credit['work_year']

# %%
_, axes = plt.subplots(nrows=len(amt_cols), figsize=(10, 20))
for col, ax in zip(amt_cols, axes):
    sns.boxplot(credit[col], ax=ax)
plt.show()

# %% [markdown]
# ## 变量分箱

# %%
credit.describe()
# Out:
#                  ID   CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# count  3.645700e+04  36457.000000  36457.000000     36457.000000
# mean   5.078227e+06      0.329895      0.379708         0.672189
# std    4.187524e+04      0.470181      0.485321         0.469422
# min    5.008804e+06      0.000000      0.000000         0.000000
# 25%    5.042028e+06      0.000000      0.000000         0.000000
# 50%    5.074614e+06      0.000000      0.000000         1.000000
# 75%    5.115396e+06      1.000000      1.000000         1.000000
# max    5.150487e+06      1.000000      1.000000         1.000000
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL           age     work_year  \
# count  36457.000000      36457.000000  36457.000000  36457.000000
# mean       0.430315        186.685737     43.767598      7.247955
# std        0.742367        101.789226     11.508356      5.890187
# min        0.000000         27.000000     20.517808      0.046575
# 25%        0.000000        121.500000     34.142466      3.202740
# 50%        0.000000        157.500000     42.638356      6.898630
# 75%        1.000000        225.000000     53.254795      8.638356
# max       19.000000       1575.000000     68.909589     43.049315
#
#        FLAG_WORK_PHONE    FLAG_PHONE    FLAG_EMAIL  CNT_FAM_MEMBERS  \
# count     36457.000000  36457.000000  36457.000000     36457.000000
# mean          0.225526      0.294813      0.089722         2.198453
# std           0.417934      0.455965      0.285787         0.911686
# min           0.000000      0.000000      0.000000         1.000000
# 25%           0.000000      0.000000      0.000000         2.000000
# 50%           0.000000      0.000000      0.000000         2.000000
# 75%           0.000000      1.000000      0.000000         3.000000
# max           1.000000      1.000000      1.000000        20.000000
#
#              target  month_on_book
# count  36457.000000   36457.000000
# mean       0.016897      26.164193
# std        0.128886      16.501854
# min        0.000000      -0.000000
# 25%        0.000000      12.000000
# 50%        0.000000      24.000000
# 75%        0.000000      39.000000
# max        1.000000      60.000000

# %%
feat_cols: list = credit.columns.to_list()
feat_cols.remove('target')
feat_cols
credit_train:pd.DataFrame = credit[feat_cols]
corr_mat = credit_train.corr()
_, _ = plt.subplots(figsize=(12, 9))
print(len(feat_cols))
sns.heatmap(corr_mat, vmax=.8, square=True)
# Out:
# 18

# %% [markdown]
# 小孩个数和家庭成员个数显然相关

# %% [markdown]
# * ### 小孩个数

# %%
credit[credit['CNT_CHILDREN'] >= 2].count()['CNT_CHILDREN'] / credit.count()['CNT_CHILDREN']
# Out:
# 0.10324491867131141

# %% [markdown]
# 可以看出有超过2个小孩的家庭占少数，应当进行合并

# %%
credit.loc[credit['CNT_CHILDREN'] >= 2, 'CNT_CHILDREN'] = 'more'

# %%
sns.boxplot(credit['CNT_FAM_MEMBERS'])

# %% [markdown]
# * ### 家庭成员个数

# %%
# 将3个及其以上的家庭CNT_FAM_MEMBERS设为more
credit.loc[credit['CNT_FAM_MEMBERS'] >= 3, 'CNT_FAM_MEMBERS'] = 'more'

# %%
credit['CNT_FAM_MEMBERS'].value_counts()
# Out:
# 2.0     19463
# more    10007
# 1.0      6987
# Name: CNT_FAM_MEMBERS, dtype: int64

# %%
credit.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'age', 'work_year',
#        'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'target', 'month_on_book'],
#       dtype='object')

# %%
total = credit.isnull().sum().sort_values(ascending=False)
percent = (credit.isnull().sum()/credit.isnull().count()).sort_values(ascending=False)
type(total)
# Out:
# pandas.core.series.Series

# %%
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                      Total  Percent
# month_on_book            0      0.0
# NAME_FAMILY_STATUS       0      0.0
# CODE_GENDER              0      0.0
# FLAG_OWN_CAR             0      0.0
# FLAG_OWN_REALTY          0      0.0
# CNT_CHILDREN             0      0.0
# AMT_INCOME_TOTAL         0      0.0
# NAME_INCOME_TYPE         0      0.0
# NAME_EDUCATION_TYPE      0      0.0
# NAME_HOUSING_TYPE        0      0.0
# target                   0      0.0
# age                      0      0.0
# work_year                0      0.0
# FLAG_WORK_PHONE          0      0.0
# FLAG_PHONE               0      0.0
# FLAG_EMAIL               0      0.0
# OCCUPATION_TYPE          0      0.0
# CNT_FAM_MEMBERS          0      0.0
# ID                       0      0.0

# %%
credit['target'].value_counts()
# Out:
# 0    35841
# 1      616
# Name: target, dtype: int64

# %%
df=credit.sample(frac=1)

# %%
fraud_df = df.loc[df['target']==1]
non_fraud_df = df.loc[df['target']==0][:616]
print(fraud_df.shape)
print(non_fraud_df.shape)
# Out:
# (616, 19)
# (616, 19)

# %%
normal_distributed = pd.concat([fraud_df, non_fraud_df])
print(normal_distributed.shape)
normal_distributed.head()
# Out:
# (1232, 19)
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY CNT_CHILDREN  \
# 36324  5104869            0             0                1            0
# 36215  5051085            1             1                0         more
# 36237  5054525            0             0                0         more
# 36200  5047783            0             1                1            0
# 36283  5090166            0             0                1            1
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 36324             112.5               Working               Higher education
# 36215             315.0               Working  Secondary / secondary special
# 36237             180.0               Working  Secondary / secondary special
# 36200             225.0  Commercial associate               Higher education
# 36283             675.0  Commercial associate  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE        age  work_year  \
# 36324               Married  House / apartment  33.189041  10.969863
# 36215               Married  House / apartment  32.978082   0.539726
# 36237  Single / not married  House / apartment  45.509589  22.928767
# 36200        Civil marriage  House / apartment  32.545205   0.843836
# 36283  Single / not married  House / apartment  42.334247   2.356164
#
#        FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 36324                0           0           0     Accountants
# 36215                0           0           0        Laborers
# 36237                0           0           0         Unknown
# 36200                1           1           0     Sales staff
# 36283                0           0           0  Security staff
#
#       CNT_FAM_MEMBERS  target  month_on_book
# 36324               2       1           26.0
# 36215            more       1           15.0
# 36237            more       1            9.0
# 36200               2       1           47.0
# 36283               2       1           18.0

# %%
new_df = normal_distributed.sample(frac=1, random_state=42)
print(new_df.shape)
new_df.head()
# Out:
# (1232, 19)
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY CNT_CHILDREN  \
# 28309  5116035            1             1                1            0
# 24054  5096606            0             1                0            1
# 4856   5024917            0             0                1            0
# 18488  5069216            0             1                1            0
# 15948  5065399            0             1                1            0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 28309             126.0               Working               Higher education
# 24054             225.0               Working               Higher education
# 4856              112.5             Pensioner  Secondary / secondary special
# 18488             256.5  Commercial associate               Higher education
# 15948             157.5             Pensioner               Higher education
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE        age  work_year  \
# 28309  Single / not married  House / apartment  39.786301   2.364384
# 24054        Civil marriage  House / apartment  37.063014   2.684932
# 4856                Married  House / apartment  59.813699   7.247955
# 18488               Married  House / apartment  30.712329   4.723288
# 15948             Separated  House / apartment  63.673973   7.247955
#
#        FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 28309                1           0           0        Managers
# 24054                1           1           0      Core staff
# 4856                 0           1           0         Unknown
# 18488                1           0           0     Accountants
# 15948                0           0           0         Unknown
#
#       CNT_FAM_MEMBERS  target  month_on_book
# 28309               1       1           32.0
# 24054            more       0           35.0
# 4856                2       1           37.0
# 18488               2       1           60.0
# 15948               1       0           13.0

# %%
print('Distribution of the target in the subample dataset')
print(new_df['target'].value_counts()/len(new_df))
sns.countplot('target', data=new_df)
plt.title('Equally Distributed Classes', fontsize=14)
plt.show()
# Out:
# Distribution of the target in the subample dataset
# 1    0.5
# 0    0.5
# Name: target, dtype: float64

# %%
g = sns.FacetGrid(new_df, col='target')
g.map(plt.hist, 'month_on_book', bins=10)

# %%
import pandas as pd
import numpy as np
 
#读取数据集，至少包含变量和target两列
sample_set = new_df
 
def calc_score_median(sample_set, var):
    '''
    计算相邻评分的中位数，以便进行决策树二元切分
    param sample_set: 待切分样本
    param var: 分割变量名称
    '''
    var_list = list(np.unique(sample_set[var]))
    var_median_list = []
    for i in range(len(var_list) -1):
        var_median = (var_list[i] + var_list[i+1]) / 2
        var_median_list.append(var_median)
    return var_median_list

# %%
def choose_best_split(sample_set, var, min_sample):
    '''
    使用CART分类决策树选择最好的样本切分点
    返回切分点
    param sample_set: 待切分样本
    param var: 分割变量名称
    param min_sample: 待切分样本的最小样本量(限制条件)
    '''
    # 根据样本评分计算相邻不同分数的中间值
    score_median_list = calc_score_median(sample_set, var)
    median_len = len(score_median_list)
    sample_cnt = sample_set.shape[0]
    sample1_cnt = sum(sample_set['target'])
    sample0_cnt =  sample_cnt- sample1_cnt
    Gini = 1 - np.square(sample1_cnt / sample_cnt) - np.square(sample0_cnt / sample_cnt)
    
    bestGini = 0.0; bestSplit_point = 0.0; bestSplit_position = 0.0
    for i in range(median_len):
        left = sample_set[sample_set[var] < score_median_list[i]]
        right = sample_set[sample_set[var] > score_median_list[i]]
        
        left_cnt = left.shape[0]; right_cnt = right.shape[0]
        left1_cnt = sum(left['target']); right1_cnt = sum(right['target'])
        left0_cnt =  left_cnt - left1_cnt; right0_cnt =  right_cnt - right1_cnt
        left_ratio = left_cnt / sample_cnt; right_ratio = right_cnt / sample_cnt
        
        if left_cnt < min_sample or right_cnt < min_sample:
            continue
        
        Gini_left = 1 - np.square(left1_cnt / left_cnt) - np.square(left0_cnt / left_cnt)
        Gini_right = 1 - np.square(right1_cnt / right_cnt) - np.square(right0_cnt / right_cnt)
        Gini_temp = Gini - (left_ratio * Gini_left + right_ratio * Gini_right)
        if Gini_temp > bestGini:
            bestGini = Gini_temp; bestSplit_point = score_median_list[i]
            if median_len > 1:
                bestSplit_position = i / (median_len - 1)
            else:
                bestSplit_position = i / median_len
        else:
            continue
               
    Gini = Gini - bestGini
    return bestSplit_point, bestSplit_position

# %%
def bining_data_split(sample_set, var, min_sample, split_list):
  '''
  划分数据找到最优分割点list
  param sample_set: 待切分样本
  param var: 分割变量名称
  param min_sample: 待切分样本的最小样本量(限制条件)
  param split_list: 最优分割点list
  '''
  split, position = choose_best_split(sample_set, var, min_sample)
  if split != 0.0:
    split_list.append(split)
  # 根据分割点划分数据集，继续进行划分
  sample_set_left = sample_set[sample_set[var] < split]
  sample_set_right = sample_set[sample_set[var] > split]
  # 如果左子树样本量超过2倍最小样本量，且分割点不是第一个分割点，则切分左子树
  if len(sample_set_left) >= min_sample * 2 and position not in [0.0, 1.0]:
    bining_data_split(sample_set_left, var, min_sample, split_list)
  else:
    None
  # 如果右子树样本量超过2倍最小样本量，且分割点不是最后一个分割点，则切分右子树
  if len(sample_set_right) >= min_sample * 2 and position not in [0.0, 1.0]:
    bining_data_split(sample_set_right, var, min_sample, split_list)
  else:
    None

# %%
def get_bestsplit_list(sample_set, var):
  '''
  根据分箱得到最优分割点list
  param sample_set: 待切分样本
  param var: 分割变量名称
  '''
  # 计算最小样本阈值（终止条件）
  min_df = sample_set.shape[0] * 0.05
  split_list = []
  # 计算第一个和最后一个分割点
  bining_data_split(sample_set, var, min_df, split_list)
  return split_list

# %%
new_df.head()
# Out:
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY CNT_CHILDREN  \
# 28309  5116035            1             1                1            0
# 24054  5096606            0             1                0            1
# 4856   5024917            0             0                1            0
# 18488  5069216            0             1                1            0
# 15948  5065399            0             1                1            0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 28309             126.0               Working               Higher education
# 24054             225.0               Working               Higher education
# 4856              112.5             Pensioner  Secondary / secondary special
# 18488             256.5  Commercial associate               Higher education
# 15948             157.5             Pensioner               Higher education
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE        age  work_year  \
# 28309  Single / not married  House / apartment  39.786301   2.364384
# 24054        Civil marriage  House / apartment  37.063014   2.684932
# 4856                Married  House / apartment  59.813699   7.247955
# 18488               Married  House / apartment  30.712329   4.723288
# 15948             Separated  House / apartment  63.673973   7.247955
#
#        FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 28309                1           0           0        Managers
# 24054                1           1           0      Core staff
# 4856                 0           1           0         Unknown
# 18488                1           0           0     Accountants
# 15948                0           0           0         Unknown
#
#       CNT_FAM_MEMBERS  target  month_on_book
# 28309               1       1           32.0
# 24054            more       0           35.0
# 4856                2       1           37.0
# 18488               2       1           60.0
# 15948               1       0           13.0

# %%
split_list = get_bestsplit_list(sample_set, 'AMT_INCOME_TOTAL')

# %%
split_list.sort()

# %%
new_df.shape
# Out:
# (1232, 19)

# %%
sns.distplot(new_df['AMT_INCOME_TOTAL'])

# %%
new_df.describe()
# Out:
#                  ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# count  1.232000e+03  1232.000000   1232.000000      1232.000000
# mean   5.081028e+06     0.345779      0.349026         0.643669
# std    4.246029e+04     0.475815      0.476856         0.479109
# min    5.008823e+06     0.000000      0.000000         0.000000
# 25%    5.045799e+06     0.000000      0.000000         0.000000
# 50%    5.087746e+06     0.000000      0.000000         1.000000
# 75%    5.116745e+06     1.000000      1.000000         1.000000
# max    5.150337e+06     1.000000      1.000000         1.000000
#
#        AMT_INCOME_TOTAL          age    work_year  FLAG_WORK_PHONE  \
# count       1232.000000  1232.000000  1232.000000      1232.000000
# mean         184.614308    43.924936     6.873845         0.219156
# std           97.036252    11.568876     5.615880         0.413842
# min           36.000000    22.030137     0.178082         0.000000
# 25%          112.500000    33.995890     2.776027         0.000000
# 50%          157.500000    43.057534     6.519178         0.000000
# 75%          225.000000    53.680822     8.230822         0.000000
# max          900.000000    67.772603    35.260274         1.000000
#
#         FLAG_PHONE   FLAG_EMAIL       target  month_on_book
# count  1232.000000  1232.000000  1232.000000    1232.000000
# mean      0.294643     0.081981     0.500000      29.278409
# std       0.456067     0.274446     0.500203      16.655869
# min       0.000000     0.000000     0.000000      -0.000000
# 25%       0.000000     0.000000     0.000000      15.000000
# 50%       0.000000     0.000000     0.500000      28.000000
# 75%       1.000000     0.000000     1.000000      43.000000
# max       1.000000     1.000000     1.000000      60.000000

# %%
print(split_list)
def split_name(x, sp_list, feat_name):
    name = feat_name + '_'
    no = 1
    if x < sp_list[0]:
        return name + '0'
    for i in range(len(sp_list) - 1):
        if x > sp_list[i] and x < sp_list[i + 1]:
            return name + str(no)
        else:
            no += 1
    return name + str(len(sp_list))
        
new_df['AMT_INCOME_TOTAL'] = new_df['AMT_INCOME_TOTAL'].apply(func=split_name, args=(split_list, 'income'))
new_df['AMT_INCOME_TOTAL'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c42dc248888b> in <module>
# ----> 1 print(split_list)
#       2 def split_name(x, sp_list, feat_name):
#       3     name = feat_name + '_'
#       4     no = 1
#       5     if x < sp_list[0]:
#
# NameError: name 'split_list' is not defined

# %%
new_df['AMT_INCOME_TOTAL'].value_counts().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-62183ac68ee4> in <module>
# ----> 1 new_df['AMT_INCOME_TOTAL'].value_counts().sum()
#
# NameError: name 'new_df' is not defined

# %%
new_df['AMT_INCOME_TOTAL'].count()
# Out:
# 1232
